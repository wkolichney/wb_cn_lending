# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:root@localhost/wb_proj_doc')

# %%
query = """
SELECT 
    p.project_id,
    p.countryshortname,
    p.totalamt,
    msl.major_sector_code,
    msl.major_sector_name,
    sl.sector_code,
    sl.sector_name,
    ps.sector_percent
FROM projects p
JOIN project_major_sectors pms ON p.project_id = pms.project_id
JOIN major_sector_lookup msl ON pms.major_sector_code = msl.major_sector_code
JOIN project_sectors ps ON pms.project_major_sector_id = ps.project_major_sector_id
JOIN proj_sector_lookup sl ON ps.sector_code = sl.sector_code
ORDER BY p.project_id, msl.major_sector_code, sl.sector_code;
"""
df = pd.read_sql_query(query, engine)

# %%
df_agg = df[df['totalamt'].notna()]
df_agg = df_agg[df_agg['sector_percent'] > 0]
df_agg['sector_percent'] = df_agg['sector_percent'] / 100
df_agg['allocated_amount'] = df_agg['totalamt'] * df_agg['sector_percent']
df_agg.to_csv('project_sector_details.csv', index=False)

# %%
df
# Out:
#       project_id countryshortname     totalamt major_sector_code  \
# 0        P000001           Africa          NaN                AX
# 1        P000001           Africa          NaN                BX
# 2        P000001           Africa          NaN                SX
# 3        P000001           Africa          NaN                TX
# 4        P000001           Africa          NaN                WX
# ...          ...              ...          ...               ...
# 58191    P515255         Viet Nam  174540000.0               AAX
# 58192    P515255         Viet Nam  174540000.0               AAX
# 58193    P515255         Viet Nam  174540000.0               AAX
# 58194    P515255         Viet Nam  174540000.0               BBX
# 58195    P515255         Viet Nam  174540000.0               WWX
#
#                                    major_sector_name sector_code  \
# 0           FY17 - Agriculture, Fishing and Forestry          AZ
# 1                       FY17 - Public Administration          BH
# 2                           FY17 - Social Protection          SA
# 3                              FY17 - Transportation          TA
# 4      FY17 - Water, Sanitation and Waste Management          WZ
# ...                                              ...         ...
# 58191              Agriculture, Fishing and Forestry         AAI
# 58192              Agriculture, Fishing and Forestry         AAK
# 58193              Agriculture, Fishing and Forestry         AAT
# 58194                          Public Administration         BBC
# 58195         Water, Sanitation and Waste Management         WWW
#
#                                              sector_name  sector_percent
# 0         FY17 - Other Agriculture, Fishing and Forestry            22.0
# 1                         FY17 - Sub-National Government            26.0
# 2                               FY17 - Social Protection            26.0
# 3                                     Roads and highways            22.0
# 4      FY17 - Other Water Supply, Sanitation and Wast...             4.0
# ...                                                  ...             ...
# 58191                            Irrigation and Drainage             0.0
# 58192  Public Administration - Agriculture, Fishing, ...             0.0
# 58193                                           Forestry             0.0
# 58194              Central Government (Central Agencies)             0.0
# 58195                                    Water Resources             0.0
#
# [58196 rows x 8 columns]
