# %%
import re

# %%
test = "Broadband Connectivity,Data Infrastructure,Data Sharing, Data Exchange and Interoperability,E-Signatures and Trust Services,Identification Systems and Civil Registration,Intermediate and Advanced Digital Skills,Mitigation,Other Emerging Technologies (IoT, Quantum, Blockchain, etc.),Trade Facilitation and Trade Logistics, Innovation, Technology, and Green Competitiveness,AI and Emerging Technologies"

# split only on comma NOT followed by a space
themes = re.split(r',(?! )', test)
for t in themes:
    print(repr(t))
# Out:
# 'Broadband Connectivity'
# 'Data Infrastructure'
# 'Data Sharing, Data Exchange and Interoperability'
# 'E-Signatures and Trust Services'
# 'Identification Systems and Civil Registration'
# 'Intermediate and Advanced Digital Skills'
# 'Mitigation'
# 'Other Emerging Technologies (IoT, Quantum, Blockchain, etc.)'
# 'Trade Facilitation and Trade Logistics, Innovation, Technology, and Green Competitiveness'
# 'AI and Emerging Technologies'
